# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import VotingClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.utils import resample
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_auc_score, precision_score, recall_score, log_loss, accuracy_score
from sklearn.metrics import RocCurveDisplay
from sklearn.tree import DecisionTreeClassifier

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('loan_applic.csv')
df.head()
# Out:
#   Application Number  Application: Buy Rate  Application: Funded Amount  \
# 0         APP-299936                   1.25                      9000.0
# 1         APP-299718                   1.25                      9500.0
# 2         APP-299671                   1.25                      6000.0
# 3         APP-299367                   1.25                     15000.0
# 4         APP-299364                   1.25                     14000.0
#
#    Application: BPA Broker Negotiation  Application: Origination Fee  \
# 0                                    0                           2.0
# 1                                    0                           2.0
# 2                                    0                           2.0
# 3                                    0                           2.0
# 4                                    0                           2.0
#
#   Application: Remittance Frequency Primary Contact Gender  \
# 0                             Daily                    NaN
# 1                             Daily                   Male
# 2                             Daily                   Male
# 3                             Daily                   Male
# 4                             Daily                 Female
#
#   Application: Close Date  customer Age   Amount  ... Satisfactory  \
# 0                1/3/2017          35.0   9000.0  ...         40.0
# 1                1/3/2017          47.0   9500.0  ...         24.0
# 2                1/3/2017          58.0   6000.0  ...         15.0
# 3                1/3/2017          62.0  15000.0  ...          8.0
# 4                1/3/2017          64.0  14000.0  ...         22.0
#
#    Shipping State  Sum of Monthly Personal Debt  Time In Business Actual  \
# 0              NJ                        4792.0                     24.0
# 1              OH                        2867.0                     17.7
# 2              NY                        1331.0                     17.5
# 3              MN                       16491.0                      5.1
# 4              PA                        1373.0                      1.5
#
#        Type  Volume - 4 Months Ago Volume - 6 Months Ago  \
# 0  New Deal                   0.00                     0
# 1  New Deal               35205.42              29288.31
# 2  New Deal                6299.58               4799.65
# 3  New Deal                   0.00                     0
# 4  New Deal                   0.00                     0
#
#   Volume - Three Months Ago  Yearly Total Sales  Outcome
# 0                  11605.73           128688.72      Neg
# 1                  30209.32           351830.88      Neg
# 2                   9281.73            132113.4      Neg
# 3                  44114.52            448156.8      Pos
# 4                  16168.17           205465.32      Pos
#
# [5 rows x 47 columns]

# %%
df_subset = df.iloc[:, 30:]

df_subset
# Out:
#       Months  Number of Trade Lines Office Space  Open Bankruptcy Position  \
# 0       6.43                   40.0         Rent              0.0    First
# 1       6.29                   25.0         Rent              0.0   Second
# 2       6.29                   20.0         Rent              0.0   Second
# 3       6.29                   24.0          Own              0.0    First
# 4       6.29                   24.0         Rent              0.0    First
# ...      ...                    ...          ...              ...      ...
# 9790    8.38                   29.0         Rent              0.0    First
# 9791   12.00                   16.0          Own              0.0    First
# 9792    6.29                   15.0         Rent              0.0    First
# 9793    7.33                   17.0         Rent              1.0    First
# 9794    8.38                   12.0         Rent              0.0   Second
#
#       Public Records  Sales to Payment  Satisfactory Shipping State  \
# 0                0.0             18.00          40.0             NJ
# 1                0.0             18.00          24.0             OH
# 2                0.0              6.50          15.0             NY
# 3                3.0              0.00           8.0             MN
# 4                0.0              0.00          22.0             PA
# ...              ...               ...           ...            ...
# 9790             0.0              0.00          28.0             TX
# 9791             0.0              0.00          15.0             LA
# 9792             0.0              0.00          15.0             PA
# 9793             1.0              0.00          13.0             CA
# 9794             0.0              9.72          12.0             NJ
#
#       Sum of Monthly Personal Debt  Time In Business Actual            Type  \
# 0                           4792.0                     24.0        New Deal
# 1                           2867.0                     17.7        New Deal
# 2                           1331.0                     17.5        New Deal
# 3                          16491.0                      5.1        New Deal
# 4                           1373.0                      1.5        New Deal
# ...                            ...                      ...             ...
# 9790                        2400.0                     19.8    Paid Renewal
# 9791                        7184.0                     28.0  Potential Dupe
# 9792                        1865.0                      5.6    Paid Renewal
# 9793                        5138.0                     18.6        New Deal
# 9794                        3882.0                      7.0         Renewal
#
#       Volume - 4 Months Ago Volume - 6 Months Ago Volume - Three Months Ago  \
# 0                      0.00                     0                  11605.73
# 1                  35205.42              29288.31                  30209.32
# 2                   6299.58               4799.65                   9281.73
# 3                      0.00                     0                  44114.52
# 4                      0.00                     0                  16168.17
# ...                     ...                   ...                       ...
# 9790                    NaN                   NaN                 152267.44
# 9791                    NaN                   NaN                1034011.52
# 9792                    NaN                   NaN                       NaN
# 9793              207219.75                   NaN                 134922.09
# 9794                    NaN                   NaN                       NaN
#
#      Yearly Total Sales Outcome
# 0             128688.72     Neg
# 1             351830.88     Neg
# 2              132113.4     Neg
# 3              448156.8     Pos
# 4             205465.32     Pos
# ...                 ...     ...
# 9790         4913317.56     Pos
# 9791        10866517.08     Pos
# 9792          507148.68     Pos
# 9793         2118071.88     Pos
# 9794         1076508.36     Pos
#
# [9795 rows x 17 columns]

# %%
columns_to_keep = [
    'Application: Buy Rate',
    'Application: Funded Amount',
    'Application: BPA Broker Negotiation',
    'Application: Origination Fee',
    'customer Age',
    'Amount',
    'Satisfactory',
    'Time In Business Actual',
    'Sum of Monthly Personal Debt',
    'Yearly Total Sales',
    'Outcome',
    'crime_record',
    'Volume - 4 Months Ago',
    'Volume - 6 Months Ago',
    'Volume - Three Months Ago',
    'Average Daily Negatives',
    'Average Monthly Sales',
    'Avg Daily Bank Balance',
    'Avg Number of Monthly Deposits',
    'Brokers submitted All Time',
    'Brokers submitted last 1 month',
    'Brokers submitted last 3 months',
    'Brokers submitted last 6 months',
    'Credit Score',
    'Daily Bank Balance v/s Daily Payment',
    'Days',
    'Factor Rate',
    'Inquiry Count',
    'Months',
    'Number of Trade Lines',
    'Open Bankruptcy',
    'Public Records',
    'Sales to Payment',
    'Satisfactory',
    'Sum of Monthly Personal Debt',
    'Time In Business Actual'
]

df = df[columns_to_keep]

df.head()
#type
#crime record
# Out:
#    Application: Buy Rate  Application: Funded Amount  \
# 0                   1.25                      9000.0
# 1                   1.25                      9500.0
# 2                   1.25                      6000.0
# 3                   1.25                     15000.0
# 4                   1.25                     14000.0
#
#    Application: BPA Broker Negotiation  Application: Origination Fee  \
# 0                                    0                           2.0
# 1                                    0                           2.0
# 2                                    0                           2.0
# 3                                    0                           2.0
# 4                                    0                           2.0
#
#    customer Age   Amount Satisfactory  Time In Business Actual  \
# 0          35.0   9000.0         40.0                     24.0
# 1          47.0   9500.0         24.0                     17.7
# 2          58.0   6000.0         15.0                     17.5
# 3          62.0  15000.0          8.0                      5.1
# 4          64.0  14000.0         22.0                      1.5
#
#    Sum of Monthly Personal Debt Yearly Total Sales  ... Factor Rate  \
# 0                        4792.0          128688.72  ...        1.37
# 1                        2867.0          351830.88  ...        1.35
# 2                        1331.0           132113.4  ...        1.31
# 3                       16491.0           448156.8  ...        1.35
# 4                        1373.0          205465.32  ...        1.37
#
#   Inquiry Count  Months Number of Trade Lines Open Bankruptcy  Public Records  \
# 0          24.0    6.43                  40.0             0.0             0.0
# 1          18.0    6.29                  25.0             0.0             0.0
# 2          51.0    6.29                  20.0             0.0             0.0
# 3           1.0    6.29                  24.0             0.0             3.0
# 4          13.0    6.29                  24.0             0.0             0.0
#
#   Sales to Payment Satisfactory  Sum of Monthly Personal Debt  \
# 0             18.0         40.0                        4792.0
# 1             18.0         24.0                        2867.0
# 2              6.5         15.0                        1331.0
# 3              0.0          8.0                       16491.0
# 4              0.0         22.0                        1373.0
#
#    Time In Business Actual
# 0                     24.0
# 1                     17.7
# 2                     17.5
# 3                      5.1
# 4                      1.5
#
# [5 rows x 36 columns]

# %%
crime_records_set = set(df["crime_record"].tolist())

# %%
crime_records_set
# Out:
# {'drug', 'fraud', nan, 'traffic'}

# %%
outcome_column_index = df.columns.get_loc("Outcome")
crime_records_index = df.columns.get_loc("crime_record")


df.iloc[:, outcome_column_index] = df.iloc[:, outcome_column_index].replace({'Neg': 0, 'Pos': 1})

crime_record_mapping = {'drug': 2, 'fraud': 3, 'traffic': 1}
default_value = 0

df['crime_record'].replace(crime_record_mapping, inplace=True)
df['crime_record'].fillna(default_value, inplace=True)

mask = df.applymap(lambda x: isinstance(x, str)).all(axis=1)
df = df[~mask]

df.dropna(inplace=True)

# %%
df
#9191
# Out:
#       Application: Buy Rate  Application: Funded Amount  \
# 0                     1.250                      9000.0
# 1                     1.250                      9500.0
# 2                     1.250                      6000.0
# 3                     1.250                     15000.0
# 4                     1.250                     14000.0
# ...                     ...                         ...
# 9764                  1.300                     20000.0
# 9779                  1.375                     10000.0
# 9783                  1.375                     13500.0
# 9784                  1.300                     11000.0
# 9785                  1.370                     10000.0
#
#       Application: BPA Broker Negotiation  Application: Origination Fee  \
# 0                                       0                           2.0
# 1                                       0                           2.0
# 2                                       0                           2.0
# 3                                       0                           2.0
# 4                                       0                           2.0
# ...                                   ...                           ...
# 9764                                    0                           3.0
# 9779                                    0                           3.0
# 9783                                    0                           3.0
# 9784                                    0                           3.0
# 9785                                    0                           3.0
#
#       customer Age   Amount Satisfactory  Time In Business Actual  \
# 0             35.0   9000.0         40.0                     24.0
# 1             47.0   9500.0         24.0                     17.7
# 2             58.0   6000.0         15.0                     17.5
# 3             62.0  15000.0          8.0                      5.1
# 4             64.0  14000.0         22.0                      1.5
# ...            ...      ...          ...                      ...
# 9764          53.0  20000.0         21.0                      6.8
# 9779          57.0  10000.0         25.0                      3.4
# 9783          33.0  13500.0          6.0                      4.2
# 9784          38.0  11000.0         28.0                     11.6
# 9785          45.0  10000.0          9.0                      8.2
#
#       Sum of Monthly Personal Debt Yearly Total Sales  ... Factor Rate  \
# 0                           4792.0          128688.72  ...       1.370
# 1                           2867.0          351830.88  ...       1.350
# 2                           1331.0           132113.4  ...       1.310
# 3                          16491.0           448156.8  ...       1.350
# 4                           1373.0          205465.32  ...       1.370
# ...                            ...                ...  ...         ...
# 9764                        1966.0          504123.12  ...       1.400
# 9779                        9034.0          256078.32  ...       1.425
# 9783                         722.0          609484.44  ...       1.495
# 9784                        3949.0          419579.76  ...       1.380
# 9785                         999.0          324230.04  ...       1.370
#
#       Inquiry Count  Months Number of Trade Lines Open Bankruptcy  \
# 0              24.0    6.43                  40.0             0.0
# 1              18.0    6.29                  25.0             0.0
# 2              51.0    6.29                  20.0             0.0
# 3               1.0    6.29                  24.0             0.0
# 4              13.0    6.29                  24.0             0.0
# ...             ...     ...                   ...             ...
# 9764           15.0    6.81                  21.0             0.0
# 9779            1.0    6.29                  34.0             0.0
# 9783           25.0    6.29                   7.0             0.0
# 9784            8.0   11.95                  28.0             0.0
# 9785           14.0    7.33                   9.0             0.0
#
#       Public Records Sales to Payment Satisfactory  \
# 0                0.0            18.00         40.0
# 1                0.0            18.00         24.0
# 2                0.0             6.50         15.0
# 3                3.0             0.00          8.0
# 4                0.0             0.00         22.0
# ...              ...              ...          ...
# 9764             0.0             8.02         21.0
# 9779             0.0             0.00         25.0
# 9783             0.0            11.70          6.0
# 9784             0.0            12.16         28.0
# 9785             0.0             6.13          9.0
#
#       Sum of Monthly Personal Debt  Time In Business Actual
# 0                           4792.0                     24.0
# 1                           2867.0                     17.7
# 2                           1331.0                     17.5
# 3                          16491.0                      5.1
# 4                           1373.0                      1.5
# ...                            ...                      ...
# 9764                        1966.0                      6.8
# 9779                        9034.0                      3.4
# 9783                         722.0                      4.2
# 9784                        3949.0                     11.6
# 9785                         999.0                      8.2
#
# [3868 rows x 36 columns]

# %%
set(df["crime_record"].tolist())
# Out:
# {0.0, 1.0, 2.0, 3.0}

# %%
class_distribution = df['Outcome'].value_counts()

plt.figure(figsize=(6, 4))

class_distribution.plot(kind='bar', color=['blue', 'red'])
plt.title('Applications result distribution')
plt.xlabel('Result')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

print("Class Distribution:")
print(class_distribution)
# Out:
# Class Distribution:
# Outcome
# 1    2912
# 0     956
# Name: count, dtype: int64

# %%
X = df.drop(columns=["Outcome"])
y = df["Outcome"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
X.head(50)
# Out:
#     Application: Buy Rate  Application: Funded Amount  \
# 0                   1.250                      9000.0
# 1                   1.250                      9500.0
# 2                   1.250                      6000.0
# 3                   1.250                     15000.0
# 4                   1.250                     14000.0
# 5                   1.250                     20000.0
# 6                   1.250                      9000.0
# 7                   1.250                     30000.0
# 9                   1.240                      8000.0
# 10                  1.240                    111000.0
# 11                  1.250                     12800.0
# 12                  1.250                     14000.0
# 13                  1.250                      7000.0
# 14                  1.230                    250000.0
# 15                  1.240                     15000.0
# 16                  1.250                     20000.0
# 17                  1.260                    115000.0
# 18                  1.250                      9400.0
# 19                  1.250                     10500.0
# 20                  1.250                      8700.0
# 21                  1.260                     90000.0
# 22                  1.250                     16500.0
# 23                  1.250                     27500.0
# 24                  1.250                    250000.0
# 25                  1.250                     19500.0
# 28                  1.250                     10000.0
# 29                  1.240                     13500.0
# 30                  1.250                     13500.0
# 33                  1.250                     30000.0
# 34                  1.250                     11500.0
# 35                  1.270                     12500.0
# 37                  1.250                     16000.0
# 38                  1.250                     15000.0
# 39                  1.250                     25000.0
# 41                  1.240                      6000.0
# 43                  1.230                     30000.0
# 44                  1.250                     11500.0
# 45                  1.250                     12000.0
# 46                  1.260                     11500.0
# 47                  1.250                     20000.0
# 48                  1.250                     15000.0
# 49            0.0            10.65           7.0
# 50            0.0            13.55          34.0
# 51            1.0            17.62          17.0
# 52            0.0            17.81          31.0
# 53            0.0            18.00          30.0
# 54            0.0            18.00          20.0
# 55            0.0             4.25          19.0
# 56            0.0             6.13           0.0
# 59            1.0            12.55          15.0
#
#     Sum of Monthly Personal Debt  Time In Business Actual
# 0                         4792.0                     24.0
# 1                         2867.0                     17.7
# 2                         1331.0                     17.5
# 3                        16491.0                      5.1
# 4                         1373.0                      1.5
# 5                         4208.0                      8.5
# 6                         2955.0                      1.4
# 7                         5328.0                     15.9
# 9                         3716.0                      7.7
# 10                        5850.0                      5.0
# 11                        2196.0                      5.6
# 12                        8544.0                      1.5
# 13                        3470.0                      1.4
# 14                       13816.0                     25.0
# 15                        1456.0                      8.1
# 16                        4984.0                      1.9
# 17                        5136.0                      4.0
# 18                        3650.0                      9.8
# 19                        2963.0                      4.1
# 20                        4403.0                     39.7
# 21                        5379.0                      2.1
# 22                        6645.0                      2.1
# 23                        1023.0                      2.8
# 24                        3509.0                      3.9
# 25                         439.0                     13.2
# 28                         646.0                      3.6
# 29                         119.0                     12.0
# 30                        1671.0                     24.7
# 33                       51126.0                     51.7
# 34                        4207.0                     21.5
# 35                        1965.0                      2.9
# 37                        2362.0                      7.0
# 38                        3984.0                     13.2
# 39                       10441.0                      1.7
# 41                        1715.0                     17.6
# 43                        6543.0                     12.0
# 44                         965.0                      9.9
# 45                        1252.0                      2.6
# 46                        1415.0                      3.1
# 47                         874.0                      5.1
# 48                        3703.0                      8.3
# 49                        3540.0                     24.7
# 50                        3321.0                      2.8
# 51                         310.0                      1.3
# 52                         252.0                    394.2
# 53                        4444.0                     12.3
# 54                        4225.0                      3.3
# 55                        1095.0                      7.1
# 56                           0.0                      6.4
# 59                        4953.0                     48.9
#
# [50 rows x 35 columns]

# %%
models = []

X_train = X_train.replace(',', '', regex=True).astype(float)
X_test = X_test.replace(',', '', regex=True).astype(float)

for i in range(0):
    
    model = DecisionTreeClassifier()
    model.fit(X_train, y_train)
    models.append(model)

# %%
from sklearn.ensemble import AdaBoostClassifier

X_train = X_train.replace(',', '', regex=True).astype(float)
X_test = X_test.replace(',', '', regex=True).astype(float)

for i in range(10):
    
    model = AdaBoostClassifier(n_estimators=100)
    model.fit(X_train, y_train)
    models.append(model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 9
#       6 for i in range(10):
#       8     model = AdaBoostClassifier(n_estimators=100)
# ----> 9     model.fit(X_train, y_train)
#      10     models.append(model)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:171, in BaseWeightBoosting.fit(self, X, y, sample_weight)
#     168 sample_weight[zero_weight_mask] = 0.0
#     170 # Boosting step
# --> 171 sample_weight, estimator_weight, estimator_error = self._boost(
#     172     iboost, X, y, sample_weight, random_state
#     173 )
#     175 # Early termination
#     176 if sample_weight is None:
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:579, in AdaBoostClassifier._boost(self, iboost, X, y, sample_weight, random_state)
#     540 """Implement a single boost.
#     541
#     542 Perform a single boost according to the real multi-class SAMME.R
#    (...)
#     576     If None then boosting has terminated early.
#     577 """
#     578 if self.algorithm == "SAMME.R":
# --> 579     return self._boost_real(iboost, X, y, sample_weight, random_state)
#     581 else:  # elif self.algorithm == "SAMME":
#     582     return self._boost_discrete(iboost, X, y, sample_weight, random_state)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:588, in AdaBoostClassifier._boost_real(self, iboost, X, y, sample_weight, random_state)
#     585 """Implement a single boost using the SAMME.R real algorithm."""
#     586 estimator = self._make_estimator(random_state=random_state)
# --> 588 estimator.fit(X, y, sample_weight=sample_weight)
#     590 y_predict_proba = estimator.predict_proba(X)
#     592 if iboost == 0:
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:959, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     928 @_fit_context(prefer_skip_nested_validation=True)
#     929 def fit(self, X, y, sample_weight=None, check_input=True):
#     930     """Build a decision tree classifier from the training set (X, y).
#     931
#     932     Parameters
#    (...)
#     956         Fitted estimator.
#     957     """
# --> 959     super()._fit(
#     960         X,
#     961         y,
#     962         sample_weight=sample_weight,
#     963         check_input=check_input,
#     964     )
#     965     return self
#
# File ~\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:284, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     281 self.n_outputs_ = y.shape[1]
#     283 if is_classification:
# --> 284     check_classification_targets(y)
#     285     y = np.copy(y)
#     287     self.classes_ = []
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\multiclass.py:215, in check_classification_targets(y)
#     207 y_type = type_of_target(y, input_name="y")
#     208 if y_type not in [
#     209     "binary",
#     210     "multiclass",
#    (...)
#     213     "multilabel-sequences",
#     214 ]:
# --> 215     raise ValueError(
#     216         f"Unknown label type: {y_type}. Maybe you are trying to fit a "
#     217         "classifier, which expects discrete classes on a "
#     218         "regression target with continuous values."
#     219     )
#
# ValueError: Unknown label type: unknown. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.

# %%
voting_clf = VotingClassifier(estimators=[
    ('0', models[0]),
    ('1', models[1]),
    ('2', models[2]),
    ('3', models[3]),
    ('4', models[4]),
    ('5', models[5]),
    ('6', models[6]),
    ('7', models[7]),
    ('8', models[8]),
    ('9', models[9]),
], voting='hard')

voting_clf.fit(X_train, y_train)

y_pred = voting_clf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
classification_report = classification_report(y_test, y_pred)
score = voting_clf.score(X_test, y_test)

# %%
print("VotingClassifier accuracy:", accuracy)
print("VotingClassifier Score:", score) 
print("VotingClassifier Confusion Matrix:")
print(conf_matrix)
print("VotingClassifier Classification Report:")
print(classification_report)

# %% [markdown]
# # 3 - 7
#
# <!-- VotingClassifier accuracy: 0.7545219638242894
# VotingClassifier Score: 0.7545219638242894
# VotingClassifier Confusion Matrix:
# [[  79  297]
#  [  83 1089]]
# VotingClassifier Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.49      0.21      0.29       376
#            1       0.79      0.93      0.85      1172
#
#     accuracy                           0.75      1548
#    macro avg       0.64      0.57      0.57      1548
# weighted avg       0.71      0.75      0.72      1548 -->

# %%
# !pip install tensorflow
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow import keras

# %%
def focal_loss(y_true, y_pred, gamma=2.0, alpha=0.25):
    ce_loss = tf.keras.losses.binary_crossentropy(y_true, y_pred, from_logits=False)
    pt = tf.exp(-ce_loss)
    focal_loss = alpha * ((1 - pt) ** gamma) * ce_loss
    return focal_loss

# %%
# Simple Perceptrone
model = keras.Sequential([
    tf.keras.layers.Dense(1, activation='sigmoid', input_shape=(X_train.shape[1],))
])

model.compile(optimizer='adam', loss=focal_loss, metrics=['accuracy'])

history_focal = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))

y_pred_focal = model.predict(X_test)
focal_loss_value = model.evaluate(X_test, y_test)
focal_conf_matrix = confusion_matrix(y_test, y_pred_focal.round())

# %%
print("\n\n\nFocal Loss and Accuracy:")
print(focal_loss_value)
print(classification_report(y_test, (y_pred_focal > 0.5).astype(int)))
print("\nFocal Confusion Matrix:")
# TP  FP
# FN  TN
print(focal_conf_matrix)
